# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b7702f3-77ed-42ec-9c0a-4fb7c0282268" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b7702f3-77ed-42ec-9c0a-4fb7c0282268">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train (1).csv

# %%
dfa = pd.read_csv(io.BytesIO(uploaded['train.csv']))
dfa.head()
# Out:
#       id                                              title  Rating maincateg  \
# 0  16695  Fashionable & Comfortable Bellies For Women  (...     3.9     Women
# 1   5120  Combo Pack of 4 Casual Shoes Sneakers For Men ...     3.8       Men
# 2  18391         Cilia Mode Leo Sneakers For Women  (White)     4.4     Women
# 3    495                            Men Black Sports Sandal     4.2       Men
# 4  16408                            Men Green Sports Sandal     3.9       Men
#
#    platform  price1  actprice1 Offer %  norating1  noreviews1  star_5f  \
# 0  Flipkart     698        999  30.13%       38.0         7.0     17.0
# 1  Flipkart     999       1999  50.03%      531.0        69.0    264.0
# 2  Flipkart    2749       4999  45.01%       17.0         4.0     11.0
# 3  Flipkart     518        724  15.85%    46413.0      6229.0   1045.0
# 4  Flipkart    1379       2299  40.02%       77.0         3.0     35.0
#
#    star_4f  star_3f  star_2f  star_1f  fulfilled1
# ...

# %%
dfa.shape
# Out:
# (15730, 16)

# %%
dfa.describe()
# Out:
#                  id        Rating        price1     actprice1      norating1  \
# count  15730.000000  15730.000000  15730.000000  15730.000000   15052.000000
# mean   10479.541577      4.012873    688.070693   1369.286777    3057.660776
# std     6080.166276      0.298440    649.409586   1240.900227   11846.965689
# min        3.000000      0.000000     69.000000     42.000000       1.000000
# 25%     5212.000000      3.900000    349.000000    699.000000      63.000000
# 50%    10458.500000      4.000000    474.000000    999.000000     308.000000
# 75%    15766.750000      4.200000    699.000000   1299.000000    1526.000000
# max    20973.000000      5.000000   5998.000000  13499.000000  289973.000000
#
#          noreviews1        star_5f       star_4f       star_3f       star_2f  \
# count  15152.000000   15142.000000  15191.000000  15499.000000  15730.000000
# mean     423.976307    1585.239466    655.923310    357.260662    155.085188
# ...

# %%
dfa['Rating'].fillna(value = 4.011089, inplace = True)
dfa['star_5f'].fillna(value = 1557.443199, inplace = True)
dfa['star_4f'].fillna(value = 655.923310, inplace = True)
dfa['star_3f'].fillna(value = 357.260662, inplace = True)
dfa['star_1f'].fillna(value = 1035.085288, inplace = True)

# %%
dfa.isnull().sum()
# Out:
# id              0
# title           0
# Rating          0
# maincateg     526
# platform        0
# price1          0
# actprice1       0
# Offer %         0
# norating1     678
# noreviews1    578
# star_5f         0
# star_4f         0
# star_3f         0
# star_2f         0
# star_1f         0
# fulfilled1      0
# dtype: int64

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-994f4daf-7ca6-4a3f-84ab-55f56c3e22a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-994f4daf-7ca6-4a3f-84ab-55f56c3e22a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv

# %%
dfb = pd.read_csv(io.BytesIO(uploaded['test.csv']))
dfb.head()
# Out:
#       id                                              title  Rating maincateg  \
# 0   2242                            Casuals For Men  (Blue)     3.8       Men
# 1  20532                           Women Black Flats Sandal     3.9     Women
# 2  10648                           Women Gold Wedges Sandal     3.9     Women
# 3  20677  Men's Height Increasing High Heel Formal Party...     3.9       Men
# 4  12593                             Loafers For Men  (Tan)     3.9       Men
#
#    platform  actprice1  norating1  noreviews1  star_5f  star_4f  star_3f  \
# 0  Flipkart        999      27928        3543  14238.0     4295     3457
# 1  Flipkart        499       3015         404   1458.0      657      397
# 2  Flipkart        999        449          52    229.0       70       71
# 3  Flipkart       2999        290          40    141.0       51       49
# 4  Flipkart        999       2423         326   1265.0      414      293
#
#    star_2f  star_1f  fulfilled1
# ...

# %%
dfb.shape
# Out:
# (5244, 14)

# %%
dfb['Rating'].fillna(value = 4.011089, inplace = True)
dfb['star_5f'].fillna(value = 1557.443199, inplace = True)
dfb['star_1f'].fillna(value = 1035.085288, inplace = True)

# %%
dfb.isnull().sum()
# Out:
# Rating        0
# actprice1     0
# star_5f       0
# star_4f       0
# star_3f       0
# star_2f       0
# star_1f       0
# fulfilled1    0
# dtype: int64

# %%
dfb1 = dfb['id']

# %%
dfb.drop(['title','maincateg','platform','id','platform','noreviews1','norating1'], axis=1,inplace=True)

# %%
dfb.describe()
# Out:
#             Rating     actprice1        star_5f       star_4f       star_3f  \
# count  5041.000000   5244.000000    5176.000000   5244.000000   5244.000000
# mean      4.011089   1378.657895    1557.443199    639.785469    356.356789
# std       0.301915   1280.630070    6583.766998   2991.065223   1632.732834
# min       0.000000    139.000000       0.000000      0.000000      0.000000
# 25%       3.900000    699.000000      32.000000     12.000000      7.000000
# 50%       4.000000    999.000000     156.000000     61.000000     34.000000
# 75%       4.200000   1299.000000     764.250000    310.250000    166.000000
# max       5.000000  15999.000000  151193.000000  74037.000000  49924.000000
#
#             star_2f       star_1f   fulfilled1
# count   5244.000000   5058.000000  5244.000000
# mean     154.139969    270.397786     0.604500
# std      611.006799   1035.085288     0.489004
# min        0.000000      0.000000     0.000000
# ...

# %%
corr = dfb.corr()

# %%
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16, 11));

# Generate a custom diverging colormap
cmap = sns.diverging_palette(0, 25, as_cmap=True, s = 90, l = 45, n = 5)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,annot = True,
             linewidths=.5, cbar_kws= {'orientation': 'horizontal'})

plt.title('Correlation Heatmap (for the MEAN variables)', fontsize = 25)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5]),
#  <a list of 8 Text major ticklabel objects>)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier, XGBRFClassifier
from xgboost import plot_tree, plot_importance
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE

# %%
X_train, X_test, y_train, y_test = train_test_split(dfa.drop(['Offer %','price1','title','maincateg','platform','id','platform','noreviews1','norating1'], axis=1),dfa.price1,train_size=0.8)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[5.25544042e-04, 5.37526743e-04, 5.53652740e-04, ...,
#         6.61274257e-04, 7.24855556e-04, 8.80934936e-04],
#        [2.13088771e-04, 2.27387250e-04, 2.66006826e-04, ...,
#         3.62200039e-04, 4.47967911e-04, 6.98123225e-04],
#        [5.40678850e-04, 5.52069065e-04, 5.65725630e-04, ...,
#         6.71793863e-04, 7.32683407e-04, 8.81172966e-04],
#        ...,
#        [1.08630010e-06, 1.36014216e-06, 1.66488453e-06, ...,
#         1.27021534e-05, 3.39139774e-05, 2.75781498e-04],
#        [2.25781449e-04, 2.40288349e-04, 2.75898595e-04, ...,
#         3.84517493e-04, 4.75853924e-04, 7.43844242e-04],
#        [3.76126455e-04, 3.90902426e-04, 4.35068809e-04, ...,
#         5.01788051e-04, 5.63284548e-04, 7.15635633e-04]])

# %%
model.score(X_test,y_test)
# Out:
# 0.05689764780673871

# %%
y_final_predicted = model.predict(dfb)

# %%
res = pd.DataFrame(y_final_predicted)
res.index = dfb.index
res.columns = ["price1"]

# %%
res
# Out:
#       price1
# 0        399
# 1        499
# 2        499
# 3        499
# 4        499
# ...      ...
# 5239     498
# 5240     499
# 5241     499
# 5242     499
# 5243     499
#
# [5244 rows x 1 columns]

# %%
fi=pd.concat([dfb1,res],axis=1)

# %%
fi
# Out:
#          id  price1
# 0      2242     399
# 1     20532     499
# 2     10648     499
# 3     20677     499
# 4     12593     499
# ...     ...     ...
# 5239  14033     498
# 5240    297     499
# 5241  18733     499
# 5242   6162     499
# 5243  13574     499
#
# [5244 rows x 2 columns]

# %%
fi.to_csv(r'C:\Users\agnih\Downloads\sa2022\prediction_2.csv', index = False)
